# %%
# plt.imshow(patched_data[84644,5,:,:,0])




# def dataGenerator(patched_data):
#     tensor=tf.convert_to_tensor(patched_data)
#     for i in range(len(tensor)):
#         x=tensor[i,0:10,:,:,:]
#         y=tensor[i,1:11,:,:,:]
#         yield x,y

# OUTPUT_SHAPE=(10,32,32,1)
# NUM_POINTS=2000
# BATCH_SIZE=16
# PRE_FETCH=2
# EPOCHS=2

# #dataset = tf.data.Dataset.from_generator(dataGenerator, 
# #                                          (tf.int64),
# #                                          output_shapes=(INPUT_SHAPE)
# #                                         ).batch(BATCH_SIZE)
# # batched_dataset = dataset.batch(4)
# #lambda: raw_data_gen(train_val_or_test=1)
# #To-Do : check output types
# ds = tf.data.Dataset.from_generator(lambda: dataGenerator(patched_data), output_types=(tf.float32, tf.float32), output_shapes = (OUTPUT_SHAPE,OUTPUT_SHAPE))
# ds = ds.shuffle(1000, reshuffle_each_iteration=True)
# ds = ds.batch(BATCH_SIZE).prefetch(PRE_FETCH)


# iterator = dataset.make_one_shot_iterator()
# x,y = iterator.get_next()

# time=0
# for next_element in ds:
#     time+=1
#     ne = next_element
#     if time==4:
#         break;

# def create_Model():
    
#     model=tf.keras.models.Sequential()
#     model.add(ConvLSTM2D(filters=64, kernel_size=(7, 7),
#                          input_shape=(None, 32, 32, 1), padding='same', return_sequences=True, 
#                          activation='tanh', recurrent_activation='hard_sigmoid',
#                          kernel_initializer='glorot_uniform', unit_forget_bias=True, 
#                          dropout=0.3, recurrent_dropout=0.3))
#     model.add(BatchNormalization())

#     model.add(ConvLSTM2D(filters=32, kernel_size=(7, 7), padding='same', return_sequences=True, 
#                          activation='tanh', recurrent_activation='hard_sigmoid', 
#                          kernel_initializer='glorot_uniform', unit_forget_bias=True, 
#                          dropout=0.4, recurrent_dropout=0.3))
#     model.add(BatchNormalization())
    
#     model.add(ConvLSTM2D(filters=32, kernel_size=(7, 7), padding='same', return_sequences=True, 
#                          activation='tanh', recurrent_activation='hard_sigmoid', 
#                          kernel_initializer='glorot_uniform', unit_forget_bias=True, 
#                          dropout=0.4, recurrent_dropout=0.3))
#     model.add(BatchNormalization())


#     model.add(ConvLSTM2D(filters=32, kernel_size=(7, 7), padding='same', return_sequences=True, 
#                          activation='tanh', recurrent_activation='hard_sigmoid', 
#                          kernel_initializer='glorot_uniform', unit_forget_bias=True, 
#                          dropout=0.4, recurrent_dropout=0.3))
#     model.add(BatchNormalization())
    
#     model.add(Conv3D(filters=1, kernel_size=(1, 1, 1),
#                    activation='sigmoid',
#                    padding='same', data_format='channels_last'))
    
#     ### !!! try go_backwards=True !!! ###    
    
#     print(model.summary())
    
#     return model

# model = create_Model()
# model.compile(loss='mse', optimizer='adam')

# # model.compile(
# #     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=1.0),
# #     loss= tf.keras.losses.CategoricalCrossentropy(),
# #     )
# history = model.fit(ds,epochs=2,verbose=1)
# print(model.summary())
# model.fit(ds, epochs=EPOCHS, verbose=2)
# type(ne) #tuple
# len(ne) # 2 -> x,y
# type(ne[0]) #tensorflow.python.framework.ops.EagerTensor

# xx = np.array(ne[0])
# type(xx) #numpy.ndarray"
# xx.shape #(1, 10, 32, 32, 1)


# yy = np.array(ne[1])
# type(yy) #numpy.ndarray
# yy.shape #(1, 10, 32, 32, 1)
#plt.imshow(xx[0,0,:,:,0])

# %%
import os
from Dataset.DataInput import databuilder as db
from pyhdf.SD  import *
import numpy as np
from Utility.utils import utilityfunctions as uf
import matplotlib.pyplot as plt
import tensorflow as tf



# import pandas as pd
# import numpy as np
# import datetime
# import os
# import sys
# from datetime import datetime
# from datetime import timedelta
# import matplotlib.pyplot as plt
# import h5py
# from tensorflow.keras.callbacks import EarlyStopping
# from tensorflow.keras.callbacks import ModelCheckpoint
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, MaxPooling2D, MaxPooling3D, Dropout, BatchNormalization, Flatten, Conv2D, Conv3D, AveragePooling3D, LSTM, Reshape
# from tensorflow.keras import backend as K
# from tensorflow.keras.callbacks import History 
# import warnings
# warnings.filterwarnings("ignore")
# import os
# from tensorflow.keras.utils import multi_gpu_model
# from tensorflow.keras.layers import AveragePooling2D
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv3D
# from tensorflow.keras.layers import ConvLSTM2D
